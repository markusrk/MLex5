# %%
import importlib
import import_handler
from matplotlib import pyplot as plt
# %matplotlib inline

importlib.reload(import_handler)
# Out:
# <module 'import_handler' from '/Users/markus/PycharmProjects/MLex5/import_handler.py'>

# %%
x_train,x_test,y_train,y_test = import_handler.get_normalized()
# Out:
# /Users/markus/PycharmProjects/MLex5/chars74k-lite
# TRAIN: [4648 3166  128 ..., 6115  432 3305] TEST: [3752 4761 1436 ..., 1721 5918  165]
# TRAIN: [2886 2671 3959 ..., 1677 4703 1295] TEST: [5150 2468 4834 ..., 4428 4074 4382]

# %%
from sklearn.model_selection import StratifiedShuffleSplit

sss = StratifiedShuffleSplit(n_splits=2, test_size=0.2, random_state=42)
sss.get_n_splits(x, y)

for train_index, test_index in sss.split(x, y):
   print("TRAIN:", train_index, "TEST:", test_index)
   x_train, x_test = x[train_index], x[test_index]
   y_train, y_test = y[train_index], y[test_index]

# %%
# Out:
# 1.0

# %%
for i in range(0,10):
    print(y_train[i].argmax())
    plt.imshow(x_train[i])
    plt.show()
# Out:
# 8
# 8
# 13
# 7
# 0
# 13
# 18
# 11
# 0
# 3
