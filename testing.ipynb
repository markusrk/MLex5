# %%
import import_handler
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
x, y = import_handler.import_chars74k()
# Out:
# /Users/markus/PycharmProjects/MLex5/chars74k-lite

# %%
for i in range(7020,7032):
    print(y[i].index(max(y[i])))
    plt.imshow(x[i])
    plt.show()
# Out:
# 24
# 24
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
